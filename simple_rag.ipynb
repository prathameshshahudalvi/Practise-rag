# %%
1+1
# Out:
# 2

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
llm.invoke("Hiiii")
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 37, 'total_tokens': 60, 'completion_time': 0.04308414, 'completion_tokens_details': None, 'prompt_time': 0.003197245, 'prompt_tokens_details': None, 'queue_time': 0.058404705, 'total_time': 0.046281385}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b948b-3a45-7163-9f86-9551c2b38b9c-0', usage_metadata={'input_tokens': 37, 'output_tokens': 23, 'total_tokens': 60})

# %%
from langchain_community.document_loaders import TextLoader

docs = TextLoader("essay.txt").load()
docs
# Out:
# [Document(metadata={'source': 'essay.txt'}, page_content='My name is Prathamesh Dalvi.I born in 17 May 1995. I live in Mumbai.')]

# %%
result = llm.invoke(f"What old is He on content given : {docs}")
result.content
# Out:
# "To determine the age of Prathamesh Dalvi based on the given content, we first need to establish his birthdate and then calculate his age as of the current year (2026, as per the information provided).\n\nGiven birthdate: 17 May 1995\n\nAs of 2026, to calculate his age:\n\n1. If today's date is before May 17, 2026, then:\n   - Year of birth: 1995\n   - Current year: 2026\n   - Age = Current year - Year of birth = 2026 - 1995 = 31 years\n\n2. If today's date is May 17, 2026, or after:\n   - Year of birth: 1995\n   - Current year: 2026\n   - Age = Current year - Year of birth = 2026 - 1995 = 31 years\n\nTherefore, as of 2026, Prathamesh Dalvi would be 31 years old."
